# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import tushare as ts
import warnings;warnings.simplefilter('ignore')

# %% [markdown]
# ### 1 简单金融应用和分析

# %%
hs300 = ts.get_k_data('hs300',start='2015-01-01',end='2017-06-30')

# %%
hs300.set_index('date',inplace=True)
hs300.head()

# %%
hs300['close'].plot(figsize=(8,5),grid=True,title='HS300 Close Price')

# %%
# 计算每天的连续收益，必背！！！
hs300['return'] = np.log(hs300['close']/hs300['close'].shift(1))

# %%
hs300[['close','return']].plot(subplots=True,figsize=(10,8),grid=True)

# %%
#计算股价的移动平均，必背！！！
hs300['SMA20'] = hs300['close'].rolling(window=20).mean()
hs300.tail()
# rolling(windoe=xx) 滚动xx个窗口 https://baijiahao.baidu.com/s?id=1622798772654712959&wfr=spider&for=pc

# %%
#用talib计算移动平均，talib是一个技术分析的package
import talib as ta
hs300['SMA20_talib'] = ta.SMA(np.array(hs300['close']),20)

# %%
hs300[['close','SMA20']].plot(figsize=(8,6))

# %%
hs300['SMA60']=hs300['close'].rolling(window=60,min_periods=0).mean()
hs300[['close','SMA60']].plot(figsize=(8,6))
# min_periods=0即最小移动为0天，可以补全前几个空值

# %%
import math
hs300['Mov_Vol'] = hs300['return'].rolling(window=252,min_periods=0).std()* math.sqrt(252)
hs300.head()

# %%
hs300[['close','Mov_Vol','return']].plot(figsize=(8,6),subplots=True,grid=True)

# %% [markdown]
# ### 2 爬取tushare数据并进行选股条件分析

# %% [markdown]
# 从估值角度选取股票，即在行业分类汇总的基础上，选取被低估的股票（低PE，PB)
#
# tushare官网：http://tushare.org/index.html

# %%
hs300 = ts.get_hs300s() #获得hs300的股票列表
hs300
# Out:
#           date    code  name  weight
# 0   2020-07-31  600000  浦发银行    0.73
# 1   2020-07-31  600004  白云机场    0.09
# 2   2020-07-31  600009  上海机场    0.39
# 3   2020-07-31  600010  包钢股份    0.16
# 4   2020-07-31  600011  华能国际    0.12
# ..         ...     ...   ...     ...
# 295 2020-07-31  300413  芒果超媒    0.29
# 296 2020-07-31  300433  蓝思科技    0.26
# 297 2020-07-31  300498  温氏股份    0.64
# 298 2020-07-31  300601  康泰生物    0.45
# 299 2020-07-31  300628  亿联网络    0.10
#
# [300 rows x 4 columns]

# %%
hs300 = hs300['code'].tolist() #将series/df转化成list
hs300
# Out:
# ['600000',
#  '600004',
#  '600009',
#  '600010',
#  '600011',
#  '600015',
#  '600016',
#  '600018',
#  '600019',
#  '600025',
#  '600027',
#  '600028',
#  '600029',
#  '600030',
#  '600031',
#  '600036',
#  '600038',
#  '600048',
#  '600050',
#  '600061',
#  '600066',
#  '600068',
#  '600085',
#  '600089',
#  '600104',
#  '600109',
#  '600111',
#  '600115',
#  '600118',
#  '600170',
#  '600176',
#  '600177',
#  '600183',
#  '600188',
#  '600196',
#  '600208',
#  '600219',
#  '600221',
#  '600233',
#  '600271',
#  '600276',
#  '600297',
#  '600299',
#  '600309',
#  '600332',
#  '600340',
#  '600346',
#  '600352',
#  '600362',
#  '600369',
#  '600372',
#  '600383',
#  '600390',
#  '600398',
#  '600406',
#  '600436',
#  '600438',
#  '600482',
#  '600487',
#  '600489',
#  '600498',
#  '600516',
#  '600519',
#  '600522',
#  '600547',
#  '600570',
#  '600583',
#  '600585',
#  '600588',
#  '600606',
#  '600637',
#  '600655',
#  '600660',
#  '600674',
#  '600690',
#  '600703',
#  '600705',
#  '600741',
#  '600745',
#  '600760',
#  '600795',
#  '600809',
#  '600837',
#  '600848',
#  '600867',
#  '600886',
#  '600887',
#  '600893',
#  '600900',
#  '600919',
#  '600926',
#  '600928',
#  '600958',
#  '600968',
#  '600977',
#  '600989',
#  '600998',
#  '600999',
#  '601006',
#  '601009',
#  '601012',
#  '601018',
#  '601021',
#  '601066',
#  '601077',
#  '601088',
#  '601100',
#  '601108',
#  '601111',
#  '601117',
#  '601138',
#  '601155',
#  '601162',
#  '601166',
#  '601169',
#  '601186',
#  '601198',
#  '601211',
#  '601212',
#  '601216',
#  '601225',
#  '601229',
#  '601231',
#  '601236',
#  '601238',
#  '601288',
#  '601298',
#  '601318',
#  '601319',
#  '601328',
#  '601336',
#  '601360',
#  '601377',
#  '601390',
#  '601398',
#  '601555',
#  '601577',
#  '601600',
#  '601601',
#  '601607',
#  '601618',
#  '601628',
#  '601633',
#  '601658',
#  '601668',
#  '601669',
#  '601688',
#  '601698',
#  '601727',
#  '601766',
#  '601788',
#  '601800',
#  '601808',
#  '601816',
#  '601818',
#  '601828',
#  '601838',
#  '601857',
#  '601877',
#  '601878',
#  '601881',
#  '601888',
#  '601898',
#  '601899',
#  '601901',
#  '601916',
#  '601919',
#  '601933',
#  '601939',
#  '601985',
#  '601988',
#  '601989',
#  '601992',
#  '601997',
#  '601998',
#  '603019',
#  '603156',
#  '603160',
#  '603259',
#  '603260',
#  '603288',
#  '603369',
#  '603501',
#  '603658',
#  '603799',
#  '603833',
#  '603899',
#  '603986',
#  '603993',
#  '000001',
#  '000002',
#  '000063',
#  '000066',
#  '000069',
#  '000100',
#  '000157',
#  '000166',
#  '000333',
#  '000338',
#  '000425',
#  '000538',
#  '000568',
#  '000596',
#  '000625',
#  '000627',
#  '000651',
#  '000656',
#  '000661',
#  '000671',
#  '000703',
#  '000708',
#  '000709',
#  '000723',
#  '000725',
#  '000728',
#  '000768',
#  '000776',
#  '000783',
#  '000786',
#  '000858',
#  '000860',
#  '000876',
#  '000895',
#  '000938',
#  '000961',
#  '000963',
#  '000977',
#  '001979',
#  '002001',
#  '002007',
#  '002008',
#  '002024',
#  '002027',
#  '002032',
#  '002044',
#  '002050',
#  '002120',
#  '002129',
#  '002142',
#  '002146',
#  '002153',
#  '002157',
#  '002179',
#  '002202',
#  '002230',
#  '002236',
#  '002241',
#  '002252',
#  '002271',
#  '002304',
#  '002311',
#  '002352',
#  '002371',
#  '002410',
#  '002415',
#  '002422',
#  '002456',
#  '002460',
#  '002463',
#  '002466',
#  '002468',
#  '002475',
#  '002493',
#  '002508',
#  '002555',
#  '002558',
#  '002594',
#  '002601',
#  '002602',
#  '002607',
#  '002624',
#  '002673',
#  '002714',
#  '002736',
#  '002739',
#  '002773',
#  '002841',
#  '002916',
#  '002938',
#  '002939',
#  '002945',
#  '002958',
#  '003816',
#  '300003',
#  '300014',
#  '300015',
#  '300033',
#  '300059',
#  '300122',
#  '300124',
#  '300136',
#  '300142',
#  '300144',
#  '300347',
#  '300408',
#  '300413',
#  '300433',
#  '300498',
#  '300601',
#  '300628']

# %%
#获取基本面信息
stock_basics = ts.get_stock_basics()
stock_basics
# Out:
#         name industry area      pe  outstanding  totals  totalAssets  \
# code
# 688556   N高测     专用机械   山东  118.78         0.37    1.62        13.33
# 605066   N天正     电气设备   浙江   31.50         0.71    4.01        21.50
# 688011  新光光电      元器件  黑龙江    0.00         0.41    1.00        13.16
# 600480  凌云股份     汽车配件   河北    0.00         7.63    7.65       141.48
# 002786  银宝山新     专用机械   深圳  455.84         3.80    3.81        46.61
# ...      ...      ...  ...     ...          ...     ...          ...
# 688185   康希诺     生物制药   天津    0.00         0.00    0.00        17.36
# 688229  博睿数据     软件服务   北京    0.00         0.00    0.00         2.34
# 688286  敏芯股份      元器件   江苏    0.00         0.00    0.00         3.29
# 688313  仕佳光子     通信设备   河南    0.00         0.00    0.00         9.94
# 688335  复洁环保     环境保护   上海    0.00         0.00    0.00         4.05
#
#         liquidAssets  fixedAssets  reserved  ...   bvps    pb  timeToMarket  \
# code                                         ...
# 688556         10.17         1.72      1.38  ...   5.92  8.29      20200807
# 605066         16.49         3.17      0.66  ...   3.94  3.66      20200807
# 688011         11.43         1.08     10.23  ...  12.22  4.14      20190722
# 600480         79.21        29.18     24.96  ...   5.91  1.54      20030815
# 002786         31.93         9.24      1.74  ...   2.34  4.07      20151223
# ...              ...          ...       ...  ...    ...   ...           ...
# 688185          7.30         0.83     16.20  ...   0.00  0.00             0
# 688229          2.26         0.04      0.05  ...   0.00  0.00             0
# 688286          2.60         0.40      1.30  ...   0.00  0.00             0
# 688313          5.50         3.62      2.43  ...   0.00  0.00             0
# 688335          3.71         0.10      0.83  ...   0.00  0.00             0
#
#          undp  perundp    rev  profit    gpr     npr  holders
# code
# 688556   1.54     0.95   0.00    0.00  37.65    9.37  34814.0
# 605066   4.41     1.10   0.00    0.00  29.48    8.69  72150.0
# 688011   0.88     0.88 -49.58 -127.55  54.53  -11.86   9134.0
# 600480  13.18     1.72 -21.58 -318.50  15.31   -4.83  40013.0
# 002786   2.80     0.73  28.43  105.66  14.81    0.22  31945.0
# ...       ...      ...    ...     ...    ...     ...      ...
# 688185  -3.91     0.00   0.00    0.00  91.49 -573.33      0.0
# 688229   1.50     0.00   0.00    0.00  74.73   12.33      0.0
# 688286   1.08     0.00   0.00    0.00  32.98   10.77      0.0
# 688313   0.13     0.00   0.00    0.00  25.96    8.69      0.0
# 688335   1.04     0.00   0.00    0.00  34.42    6.97      0.0
#
# [3968 rows x 22 columns]

# %%
stock_basics.reset_index(inplace=True)
stock_basics
#reset_index()重置df的索引
# Out:
#         code  name industry area      pe  outstanding  totals  totalAssets  \
# 0     688556   N高测     专用机械   山东  118.78         0.37    1.62        13.33
# 1     605066   N天正     电气设备   浙江   31.50         0.71    4.01        21.50
# 2     688011  新光光电      元器件  黑龙江    0.00         0.41    1.00        13.16
# 3     600480  凌云股份     汽车配件   河北    0.00         7.63    7.65       141.48
# 4     002786  银宝山新     专用机械   深圳  455.84         3.80    3.81        46.61
# ...      ...   ...      ...  ...     ...          ...     ...          ...
# 3963  688185   康希诺     生物制药   天津    0.00         0.00    0.00        17.36
# 3964  688229  博睿数据     软件服务   北京    0.00         0.00    0.00         2.34
# 3965  688286  敏芯股份      元器件   江苏    0.00         0.00    0.00         3.29
# 3966  688313  仕佳光子     通信设备   河南    0.00         0.00    0.00         9.94
# 3967  688335  复洁环保     环境保护   上海    0.00         0.00    0.00         4.05
#
#       liquidAssets  fixedAssets  ...   bvps    pb  timeToMarket   undp  \
# 0            10.17         1.72  ...   5.92  8.29      20200807   1.54
# 1            16.49         3.17  ...   3.94  3.66      20200807   4.41
# 2            11.43         1.08  ...  12.22  4.14      20190722   0.88
# 3            79.21        29.18  ...   5.91  1.54      20030815  13.18
# 4            31.93         9.24  ...   2.34  4.07      20151223   2.80
# ...            ...          ...  ...    ...   ...           ...    ...
# 3963          7.30         0.83  ...   0.00  0.00             0  -3.91
# 3964          2.26         0.04  ...   0.00  0.00             0   1.50
# 3965          2.60         0.40  ...   0.00  0.00             0   1.08
# 3966          5.50         3.62  ...   0.00  0.00             0   0.13
# 3967          3.71         0.10  ...   0.00  0.00             0   1.04
#
#       perundp    rev  profit    gpr     npr  holders
# 0        0.95   0.00    0.00  37.65    9.37  34814.0
# 1        1.10   0.00    0.00  29.48    8.69  72150.0
# 2        0.88 -49.58 -127.55  54.53  -11.86   9134.0
# 3        1.72 -21.58 -318.50  15.31   -4.83  40013.0
# 4        0.73  28.43  105.66  14.81    0.22  31945.0
# ...       ...    ...     ...    ...     ...      ...
# 3963     0.00   0.00    0.00  91.49 -573.33      0.0
# 3964     0.00   0.00    0.00  74.73   12.33      0.0
# 3965     0.00   0.00    0.00  32.98   10.77      0.0
# 3966     0.00   0.00    0.00  25.96    8.69      0.0
# 3967     0.00   0.00    0.00  34.42    6.97      0.0
#
# [3968 rows x 23 columns]

# %%
# loc[a,b]a选取行标签,b列标签
# 数据过滤 isin()
data1 = stock_basics.loc[stock_basics['code'].isin(hs300),['code','name','industry','pb','pe','esp','rev','profit',]]
data1.columns = ['代码','名称','行业','PE','PB','EPS','收入%','利润%']
data1
# Out:
#           代码    名称    行业     PE      PB    EPS     收入%      利润%
# 11    601216  君正集团  化工原料   4.48   34.90  0.075   45.80   -12.97
# 32    600893  航发动力    航空   4.00  334.02  0.038    3.34  2106.25
# 44    300601  康泰生物  生物制药  24.52  305.31  0.400    7.71     0.63
# 58    002236  大华股份  电器仪表   4.18   52.50  0.106  -19.47     0.50
# 87    600038  中直股份    航空   4.70  186.53  0.088  -18.24   -34.12
# ...      ...   ...   ...    ...     ...    ...     ...      ...
# 3816  300059  东方财富    证券   9.35   62.12  0.110  102.31   126.48
# 3842  300433  蓝思科技   元器件   5.52   38.16  0.201   44.60  1010.53
# 3852  600297  广汇汽车  汽车服务   0.87    0.00 -0.049  -31.36  -149.58
# 3869  601788  光大证券    证券   2.17   23.81  0.239  -17.62   -16.20
# 3877  600196  复星医药  化学制药   5.46   77.37  0.225  -12.62   -18.97
#
# [300 rows x 8 columns]

# %%
# 方法2：不重置index，通过loc直接进行索引定位
stock_basics = ts.get_stock_basics()
data1 = stock_basics.loc[hs300,['code','name','industry','pb','pe','esp','rev','profit',]]
data1.columns = ['代码','名称','行业','PE','PB','EPS','收入%','利润%']
data1

# %%
stock_profit = ts.get_profit_data(2017,1)
stock_profit
# Out:
# [Getting data:]############################################################
#         code   name     roe  net_profit_ratio  gross_profit_rate  net_profits  \
# 0     600423   ST柳化  215.12             10.30            -1.3970      40.6863
# 1     600306  *ST商城   71.97             71.48            17.3030     171.9346
# 2     000717   韶钢松山   26.83              3.19             6.2247     168.1588
# 3     600133   东湖高新   26.81             55.22            11.6396     686.8356
# 4     002893   华通热力   25.83             21.81            32.2225     112.7380
# ...      ...    ...     ...               ...                ...          ...
# 3536  300740    御家汇     NaN              9.11            51.3119      24.4876
# 3537  300746   汉嘉设计     NaN              6.91            26.7241       7.3503
# 3538  603321   梅轮电梯     NaN              6.16            28.8689       5.8602
# 3539  300848   美瑞新材     NaN               NaN                NaN          NaN
# 3540  300740    御家汇     NaN              9.11            51.3119      24.4876
#
#          eps  business_income    bips
# 0     0.1018         394.6887  0.9883
# 1     0.9651         240.5080  1.3501
# 2     0.0695        5268.7636  2.1776
# 3     1.0828        1243.7266  1.9609
# 4     1.2526         516.6846  5.7409
# ...      ...              ...     ...
# 3536  0.2040         268.6035  2.2383
# 3537  0.0465         106.2728  0.6734
# 3538  0.0254          95.1162  0.4135
# 3539     NaN              NaN     NaN
# 3540  0.2040         268.6035  2.2383
#
# [3541 rows x 9 columns]

# %%
data2 = stock_profit.loc[stock_profit['code'].isin(hs300),['code','roe','gross_profit_rate','net_profit_ratio',]]
data2.columns=['代码','ROE','毛利率','净利率']
data2
# Out:
#           代码    ROE      毛利率    净利率
# 19    002027  12.20  67.5988  45.72
# 22    600309  11.26  39.2307  19.94
# 26    002714  10.72  40.4656  34.55
# 34    300136   9.58  29.6922  28.43
# 35    002304   9.52  61.2324  36.14
# ...      ...    ...      ...    ...
# 3328  603156    NaN  45.8056  21.72
# 3355  601066    NaN  51.2235  38.59
# 3483  601066    NaN  51.2235  38.59
# 3495  601838    NaN  50.8416  41.20
# 3515  603156    NaN  45.8056  21.72
#
# [285 rows x 4 columns]

# %%
stock_growth = ts.get_growth_data(2017,1)
data3 = stock_growth.loc[stock_growth['code'].isin(hs300),['code','nprg',]]
data3.columns = ['代码','NI增长率']
data3
# Out:
# [Getting data:]#######################################################
#           代码       NI增长率
# 1     002352  22009.0595
# 20    601225   3805.2698
# 28    002601   3002.9102
# 33    000725   2443.3145
# 35    002624   2275.0723
# ...      ...         ...
# 3221  300142         NaN
# 3236  600893         NaN
# 3247  000723         NaN
# 3259  000768         NaN
# 3271  002558         NaN
#
# [281 rows x 2 columns]

# %%
from functools import reduce
import pandas as pd

#数据合并
merge = lambda x,y: pd.merge(x,y,how='left',on='代码')
data = reduce(merge,[data1,data2,data3])
data.drop_duplicates(inplace=True) #去除重复列code
data
#reduce(function,sequence)顺序迭代调用function
# Out:
#          代码    名称    行业     PE      PB    EPS     收入%      利润%   ROE      毛利率  \
# 0    601216  君正集团  化工原料   4.48   34.90  0.075   45.80   -12.97  3.75  40.3669
# 1    600893  航发动力    航空   4.00  334.02  0.038    3.34  2106.25 -0.56  18.3001
# 3    300601  康泰生物  生物制药  24.52  305.31  0.400    7.71     0.63  3.21  86.9504
# 4    002236  大华股份  电器仪表   4.18   52.50  0.106  -19.47     0.50  3.36  39.7464
# 5    600038  中直股份    航空   4.70  186.53  0.088  -18.24   -34.12  1.02  12.7824
# ..      ...   ...   ...    ...     ...    ...     ...      ...   ...      ...
# 311  300059  东方财富    证券   9.35   62.12  0.110  102.31   126.48  0.77  57.4585
# 312  300433  蓝思科技   元器件   5.52   38.16  0.201   44.60  1010.53  1.54  24.9153
# 313  600297  广汇汽车  汽车服务   0.87    0.00 -0.049  -31.36  -149.58  3.79  10.5030
# 314  601788  光大证券    证券   2.17   23.81  0.239  -17.62   -16.20  1.22  31.6875
# 315  600196  复星医药  化学制药   5.46   77.37  0.225  -12.62   -18.97  3.23  55.3378
#
#        净利率    NI增长率
# 0    28.90  85.8170
# 1    -3.30      NaN
# 3    19.26 -54.7311
# 4    10.82  28.7268
# 5     3.40  27.9821
# ..     ...      ...
# 311  42.19 -14.3836
# 312   5.36  33.2010
# 313   2.95  42.2225
# 314  33.92   1.5761
# 315  19.01   9.7340
#
# [300 rows x 12 columns]

# %% [markdown]
# 估值系数（烟蒂）：PE*PB，烟蒂越低越被低估

# %%
data['估值系数'] = data['PE']*data['PB']
data = round(data,2)
# round() 方法返回浮点数x的四舍五入值。x -- 数值表达式。n -- 数值表达式，表示从小数点位数。
data.head(5)
# Out:
#        代码     NI增长率    名称    行业    PE     PB   EPS    收入%    利润%   ROE    毛利率  \
# 0  002352  22009.06  顺丰控股  仓储物流  6.97  82.98  0.21  39.59 -28.16  3.62  20.10
# 1  601225   3805.27  陕西煤业  煤炭开采  1.26   8.17  0.24  27.28 -15.08  7.13  55.72
# 2  002601   3002.91  龙蟒佰利  化工原料  3.59  18.59  0.64  17.98   1.84  4.53  39.77
# 3  000725   2443.31  京东方Ａ   元器件  1.90  73.54  0.02  -2.17 -46.12   NaN    NaN
# 4  002624   2275.07  完美世界  影视音像  6.85  28.31  0.32  26.09  26.41  4.28  56.27
#
#      净利率    估值系数
# 0   5.00  578.37
# 1  21.78   10.29
# 2  24.89   66.74
# 3    NaN  139.73
# 4  17.03  193.92

# %%
data_filter = data.loc[(data['估值系数']<60) &(data['ROE']>5),
                       ['代码','名称','PE','PB','估值系数','ROE','收入%']]
print(data_filter)
print('筛选结果共 %d 只个股' %len(data_filter))
# Out:
#          代码    名称     PE     PB   估值系数   ROE    收入%
# 1    601225  陕西煤业   1.26   8.17  10.29  7.13  27.28
# 50   003816  中国广核   1.67  24.87  41.53  5.76   6.76
# 71   002466  天齐锂业   5.93   0.00   0.00  7.73 -27.57
# 74   600340  华夏幸福   1.37   5.87   8.04  5.64  89.64
# 111  000963  华东医药   3.53  10.37  36.61  6.95 -11.41
# 158  601318  中国平安   2.02  13.38  27.03  5.60 -13.22
# 169  601888  中国中免  21.72   0.00   0.00  5.40 -44.23
# 172  600398  海澜之家   2.06  23.09  47.57  9.13 -36.80
# 173  600115  东方航空   1.21   0.00   0.00  5.62 -48.58
# 215  000625  长安汽车   1.14  20.15  22.97  5.22 -27.76
# 245  600177   雅戈尔   1.18   7.59   8.96  5.47  51.07
# 筛选结果共 11 只个股

# %% [markdown]
# ### 2.2 先进行数据分类

# %%
# apply() 函数则会遍历每一个元素，对元素运行指定的 function
def map_func(x):
    if x['ROE']>5:
        return '成长'
    elif x['ROE']>=0:
        return '低成长'
    elif x['ROE']<0:
        return '亏损'
data['成长性'] = data.apply(map_func,axis=1)
data.head(5)
# Out:
#        代码     NI增长率    名称    行业    PE     PB   EPS    收入%    利润%   ROE    毛利率  \
# 0  002352  22009.06  顺丰控股  仓储物流  6.97  82.98  0.21  39.59 -28.16  3.62  20.10
# 1  601225   3805.27  陕西煤业  煤炭开采  1.26   8.17  0.24  27.28 -15.08  7.13  55.72
# 2  002601   3002.91  龙蟒佰利  化工原料  3.59  18.59  0.64  17.98   1.84  4.53  39.77
# 3  000725   2443.31  京东方Ａ   元器件  1.90  73.54  0.02  -2.17 -46.12   NaN    NaN
# 4  002624   2275.07  完美世界  影视音像  6.85  28.31  0.32  26.09  26.41  4.28  56.27
#
#      净利率    估值系数   成长性
# 0   5.00  578.37   低成长
# 1  21.78   10.29    成长
# 2  24.89   66.74   低成长
# 3    NaN  139.73  None
# 4  17.03  193.92   低成长

# %%
#通过成长性进行分类
def gropu_func(df):
    #返回df，按照烟蒂系数排序的前三位
    return df.sort_values(['估值系数'],ascending=True)[:2]
data_grouped = data.groupby('成长性').apply(gropu_func)
data_grouped
# Out:
#              代码   NI增长率    名称    行业     PE   PB   EPS    收入%     利润%   ROE  \
# 成长性
# 亏损  256  600583 -115.79  海油工程  石油开采   0.96  0.0 -0.07  28.33  -16.74 -0.74
#     258  300142     NaN  沃森生物  生物制药  25.80  0.0 -0.01 -36.34 -146.78 -0.92
# 低成长 76   600297   42.22  广汇汽车  汽车服务   0.87  0.0 -0.05 -31.36 -149.58  3.79
#     34   600028  140.25  中国石化  石油加工   0.68  0.0 -0.16 -22.59 -234.00  2.28
# 成长  173  600115    5.40  东方航空    空运   1.21  0.0 -0.24 -48.58 -296.06  5.62
#     169  601888    6.25  中国中免  旅游服务  21.72  0.0 -0.06 -44.23 -105.21  5.40
#
#            毛利率    净利率  估值系数  成长性
# 成长性
# 亏损  256  -7.71 -12.17   0.0   亏损
#     258  55.84 -34.00   0.0   亏损
# 低成长 76   10.50   2.95   0.0  低成长
#     34   19.90   2.85   0.0  低成长
# 成长  173  12.44  11.48   0.0   成长
#     169  30.14  12.42   0.0   成长

# %%
#通过行业进行分类
data_grouped = data.groupby('行业').apply(gropu_func)
data_grouped
# Out:
#               代码    NI增长率     名称    行业     PE      PB   EPS    收入%     利润%  \
# 行业
# IT设备 163  600271     8.75   航天信息  IT设备   3.01    0.00 -0.23 -26.68 -182.79
#      239  000977   -40.76   浪潮信息  IT设备   4.88   99.17  0.11  15.90   47.84
# 专用机械 139  002371    14.84   北方华创  专用机械  17.54  973.92  0.05  32.49   33.00
# 中成药  129  600332    18.82    白云山   中成药   2.32   12.41  0.73  -5.93  -15.85
#      137  000538    15.66   云南白药   中成药   3.55   27.11  1.00  10.53  -34.48
# ...          ...      ...    ...   ...    ...     ...   ...    ...     ...
# 食品   121  603288    20.49   海天味业    食品  27.16   76.60  0.50   7.17    9.17
# 饲料   241  002157   -41.79   正邦科技    饲料   6.39   18.23  0.36  37.37  318.63
#      208  000876    -6.03  新 希 望    饲料   5.35   22.76  0.39  26.87  144.13
# 黄金   11   601899  1250.45   紫金矿业    黄金   3.77   40.51  0.04  24.52   18.93
#      72   600489    46.63   中金黄金    黄金   2.92   83.27  0.04 -16.87  -22.40
#
#            ROE    毛利率    净利率      估值系数  成长性
# 行业
# IT设备 163  4.03  15.29   7.20      0.00  低成长
#      239  1.77  11.18   1.83    483.95  低成长
# 专用机械 139  0.05  33.30   0.38  17082.56  低成长
# 中成药  129  2.71  39.37   9.16     28.79  低成长
#      137  4.40  30.53  12.27     96.24  低成长
# ...        ...    ...    ...       ...  ...
# 食品   121  8.88  44.69  24.35   2080.46   成长
# 饲料   241  2.08  12.18   2.67    116.49  低成长
#      208  2.96   8.25   4.37    121.77  低成长
# 黄金   11   3.45  14.13   5.44    152.72  低成长
#      72   0.65  11.02   1.09    243.15  低成长
#
# [123 rows x 14 columns]

# %%
# 解释上面的代码块：
# data_growth = data[data['成长性'] == '成长'].sort_values(['估值系数'],ascending=True)
# data_growth.head()
